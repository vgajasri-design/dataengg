# %% [markdown]
# ## READ DATASETS FROM (CSV,JSON,PARQUET)

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %% [markdown]
# # CSV FILE

# %% [raw]
# ## READ DATA FEOM CSV FILE

# %%
csv_path=pd.read_csv("C:\\Users\\ghtfut\\Downloads\\csv data.zip")

# %%
print(csv_path)
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df_csv=pd.read_csv("csv data.zip")

# %%
print(df_csv)
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %% [markdown]
# ## JSON FILE

# %% [raw]
# ## READ DATASET FROM JSON FILE

# %%
json_path=pd.read_json("C:\\Users\\ghtfut\\Documents\\harinisriragunathan\\airpots.json")

# %%
print(json_path)
# Out:
#                                              airports
# 0   {'code': 'ATL', 'name': 'Hartsfield-Jackson At...
# 1   {'code': 'PEK', 'name': 'Beijing Capital Inter...
# 2   {'code': 'DXB', 'name': 'Dubai International',...
# 3   {'code': 'LAX', 'name': 'Los Angeles Internati...
# 4   {'code': 'HND', 'name': 'Tokyo Haneda', 'city'...
# 5   {'code': 'ORD', 'name': 'O'Hare International'...
# 6   {'code': 'LHR', 'name': 'London Heathrow', 'ci...
# 7   {'code': 'PVG', 'name': 'Shanghai Pudong Inter...
# 8   {'code': 'CDG', 'name': 'Paris Charles de Gaul...
# 9   {'code': 'DFW', 'name': 'Dallas/Fort Worth Int...
# 10  {'code': 'CAN', 'name': 'Guangzhou Baiyun Inte...
# 11  {'code': 'AMS', 'name': 'Amsterdam Schiphol', ...
# 12  {'code': 'FRA', 'name': 'Frankfurt Airport', '...
# 13  {'code': 'IST', 'name': 'Istanbul Airport', 'c...
# 14  {'code': 'SIN', 'name': 'Singapore Changi', 'c...
# 15  {'code': 'ICN', 'name': 'Incheon International...
# ...

# %% [markdown]
# ## PARQUET FILE

# %% [markdown]
# ## READ DATASET FROM PARQUET FILE

# %%
parquet_path=("C:\\Users\\ghtfut\\Documents\\harinisriragunathan\\titanic.parquet")

# %%
print(parquet_path)
# Out:
# C:\Users\ghtfut\Documents\harinisriragunathan\titanic.parquet

# %%
df=pd.read_parquet("titanic.parquet")

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
